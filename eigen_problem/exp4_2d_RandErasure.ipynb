# %%
from with_FEM_MassMatrix import *
from convergence import *
from Reference_Solvers import *
from Experimental_Order_Cvg import *
from plots import *

# %% [markdown]
# Example 1

# %%
alpha = 0.1
beta = 1.
NSamples =1
pList = [0.02, 0.04, 0.08, 0.1]
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
NCoarse = np.array([2,2])
Nepsilon = np.array([64,64])
NFine = np.array([128,128])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =1
np.random.seed(123)
root = 'Data/LOD_2d_randerasure/N1_Ppt02_pt1_5_K1'
type = "random_erasure"

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "LOD", reference_solver="FEM", save_files = True, plot=False, root=root)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# Root mean square absolute error of λ1:
#  [[3.18373934 2.9378933  2.54068116 2.10901352]
#  [2.69041197 2.41986171 2.05163636 1.6298677 ]
#  [2.59513758 2.33240014 1.94828117 1.55178886]
#  [2.76462634 2.48557508 2.10025039 1.69167206]]
# Root mean square absolute error of λ2:
#  [[3.18516021 2.93218866 2.48358183 2.06487067]
#  [2.68083937 2.42220339 1.9960944  1.57272721]
#  [2.58916281 2.33418238 1.89097755 1.49511885]
#  [2.75795489 2.50251869 2.03307921 1.63703708]]
# (None, None)

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 4  8 16 32]

# %% [markdown]
# Example 2

# %%
alpha = 0.1
beta = 1.
NSamples =1
pList = [0.02, 0.04, 0.08, 0.1]
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
NCoarse = np.array([4,4])
Nepsilon = np.array([128, 128])
NFine = np.array([256,256])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =3
np.random.seed(123)
root = 'Data/LOD_2d_randerasure/N1_Ppt02_pt1_5_K3/'
type = "random_erasure"

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "LOD", reference_solver="FEM", save_files = True, plot=False, root=root)
# Out:
# Root mean square absolute error of λ1:
#  [[2.56831216 2.37011856 1.80864733 1.59889401]
#  [2.5304666  2.33240807 1.77206291 1.5642502 ]
#  [2.52808245 2.32984226 1.76895554 1.56130594]
#  [2.52991514 2.33175159 1.77190399 1.56209975]]
# Root mean square absolute error of λ2:
#  [[2.56080793 2.36436764 1.78452369 1.57517639]
#  [2.52418172 2.32794346 1.74848133 1.53931346]
#  [2.52117768 2.3253115  1.74495901 1.53649068]
#  [2.5231622  2.32850325 1.74811294 1.53729515]]
# (None, None)

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %% [markdown]
# Experiment 3

# %%
alpha = 0.1
beta = 1.
NSamples =200
pList = [0.02, 0.04, 0.08, 0.1]
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
NCoarse = np.array([4,4])
Nepsilon = np.array([128, 128])
NFine = np.array([256,256])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =3
np.random.seed(123)
root = 'Data/LOD_2d_randerasure/N200_Ppt02_pt1_5_K3/'
type = "random_erasure"

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "LOD", reference_solver="FEM", save_files = True, plot=False, root=root)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/io/matlab/_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/LOD_2d_randerasure/N200_Ppt02_pt1_5_K3/_pList_NCList.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plots_cvg(root, H_Convergence=True, p_Convergence=True)
#
# File ~/Documents/gridlod-random-perturbations/eigen_problem/plots.py:49, in plots_cvg(root, H_Convergence, p_Convergence, Mean_Lam)
# ...

# %% [markdown]
# Experiment 4

# %%
alpha = 0.1
beta = 1.
NSamples =200
pList = [0.02, 0.04, 0.08, 0.1]
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
NCoarse = np.array([4,4])
Nepsilon = np.array([128, 128])
NFine = np.array([256,256])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =1
np.random.seed(123)
root = 'Data/LOD_2d_randerasure/N200_Ppt02_pt1_5_K1/'
type = "random_erasure"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 NSamples =200
#       4 pList = [0.02, 0.04, 0.08, 0.1]
# ----> 5 left = np.array([0.25, 0.25])
#       6 right = np.array([0.75, 0.75])
#       7 model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
#
# NameError: name 'np' is not defined

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "LOD", reference_solver="FEM", save_files = True, plot=False, root=root)

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)

# %% [markdown]
# Before the change of BC.

# %%
alpha = 0.1
beta = 1.
NSamples =5
pList = [0.01, 0.02, 0.03, 0.04]
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
NCoarse = np.array([4,4])
Nepsilon = np.array([64,64])
NFine = np.array([128,128])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =1
np.random.seed(123)
root = 'Data/LOD_2d_randerasure/'
type = "random_erasure"

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "LOD", reference_solver="FEM", save_files = True, plot=True, root=root)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# Hplot [array(8), array(16), array(32), array(64)]
# Root mean square absolute error of λ1:
#  [[0.09263657 0.09389272 0.09792195 0.10023147]
#  [0.02408112 0.02612161 0.02895865 0.03221232]
#  [0.00777927 0.01071725 0.01392542 0.01725001]
#  [0.00476783 0.00886254 0.01230469 0.01627659]]
# Root mean square absolute error of λ2:
#  [[0.09384075 0.09628923 0.09713396 0.10101086]
#  [0.02361583 0.02661686 0.02906687 0.03215891]
#  [0.00830502 0.0115023  0.01444026 0.01684372]
#  [0.00505445 0.00934653 0.01308494 0.01745527]]
# (None, None)

# %%
alpha = 0.1
beta = 1.
NSamples =1
pList = [0.01, 0.02]
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
NCoarse = np.array([4,4])
Nepsilon = np.array([64,64])
NFine = np.array([128,128])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =1
np.random.seed(123)
root = 'Data/LOD_2d_randerasure/'
type = "random_erasure"

# %%
plots_coeffs(Nepsilon, NFine, alpha, beta, pList, type)

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "LOD", reference_solver="FEM", save_files = True, plot=True, root=root)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# Hplot [array(8), array(16), array(32), array(64)]
# Root mean square absolute error of λ1:
#  [[0.0938185  0.09730078]
#  [0.02481935 0.02778854]
#  [0.00826012 0.0100531 ]
#  [0.00498517 0.00829421]]
# Root mean square absolute error of λ2:
#  [[0.09470774 0.09585328]
#  [0.02466612 0.02822121]
#  [0.00855612 0.01037166]
#  [0.00500091 0.00855115]]
# (None, None)

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "LOD", reference_solver="FEM", save_files = True, plot=True)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# Hplot [array(8), array(16), array(32), array(64)]
# Root mean square absolute error of λ1:
#  [[0.0941635  0.09719348]
#  [0.0253144  0.02832025]
#  [0.0083219  0.01052614]
#  [0.00498469 0.00829434]]
# Root mean square absolute error of λ2:
#  [[0.09347893 0.09695411]
#  [0.0246567  0.0282858 ]
#  [0.00856339 0.01024137]
#  [0.00500042 0.00855037]]
# (None, None)

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
EOC(NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, Neigen, root = None, use_stored_data=True)
# Out:
# Experimental Order of Convergence for λ1:
#  [array([-1.89821502, -1.78764719]), array([-1.60110504, -1.43726445]), array([-0.73956535, -0.32535189])]
# Experimental Order of Convergence for λ2:
#  [array([-1.91310561, -1.77512834]), array([-1.53851164, -1.41992253]), array([-0.77362426, -0.30297666])]
# Set of Coarse elements:
#  [ 8 16 32 64]
# (None, None, None)
