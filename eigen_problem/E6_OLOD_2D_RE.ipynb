# %%
import numpy as np
import scipy.io as sio
import time
from offline_online_alg import *
from convergence import *
from with_FEM_MassMatrix import *
from plots import *
from Experimental_Order_Cvg import *

# %%
root = 'All_Data/OO_2D_randerasure/folder_10/'
#NFine = np.array([256,256])
#Nepsilon = np.array([128,128])
#NCoarse = np.array([8,8])
#k=4
#NSamples = 200
#dim = np.size(NFine)
#Neigen = 3
#alpha = 0.1
#beta = 1
#left = np.array([0.25, 0.25])
#right = np.array([0.75, 0.75])
#pList = [0.01, 0.04, 0.08, 0.1, 0.15]
#def_value = [alpha] #, 0.5, 5.]
#value = alpha
#modelincl = {'name': 'inclvalue', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right, 'defval': value}
#np.random.seed(123)

# %%
plots_cvg(root, H_Convergence=False, p_Convergence=True)
# Out:
# hplot [ 16  32  64 128]

# %%
root = 'All_Data/OO_2D_randerasure/folder_9/'
#NFine = np.array([256,256])
#Nepsilon = np.array([64,64])
#NCoarse = np.array([4,4])
#k=3
#NSamples = 200
#dim = np.size(NFine)
#Neigen = 3
#alpha = 1
#beta = 10
#left = np.array([0.25, 0.25])
#right = np.array([0.75, 0.75])
#pList = [0.01, 0.05, 0.1, 0.15]
#def_value = [alpha] #, 0.5, 5.]
#value = alpha
#modelincl = {'name': 'inclvalue', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right, 'defval': value}
#np.random.seed(1)

# %%
plots_cvg(root, H_Convergence=False, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
root = 'All_Data/OO_2D_randerasure/folder_8/'

# %%
plots_cvg(root, H_Convergence=False, p_Convergence=True)
# Out:
# hplot [ 16  32  64 128]

# %%
root = 'All_Data/OO_2D_randerasure/folder_7/'

# %%
plots_cvg(root, H_Convergence=False, p_Convergence=True)
# Out:
# hplot [ 16  32  64 128]

# %%
NFine = np.array([256,256])
Nepsilon = np.array([64,64])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
alpha = 0.1
beta = 1
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)
root = 'All_Data/OO_2D_randerasure/folder_6/'

# %%
plots_cvg(root, H_Convergence=False, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
plots_cvg(root, H_Convergence=False, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
plots_coeffs(Nepsilon, NFine, alpha, beta, pList, "random_erasure")

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256,256])
Nepsilon = np.array([64,64])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
alpha = 0.1
beta = 1
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList =  [0.002,0.004,0.006,0.008,0.01]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)
root = 'All_Data/OO_2D_randerasure/folder_4/'

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256,256])
Nepsilon = np.array([64,64])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
alpha = 0.1
beta = 1
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)
root = 'All_Data/OO_2D_randerasure/folder_2/'

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256,256])
Nepsilon = np.array([64,64])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
alpha = 0.1
beta = 1
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)
root = 'All_Data/OO_2D_randerasure/folder_2/'

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256,256])
Nepsilon = np.array([64,64])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
alpha = 1
beta = 10
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)
root = 'All_Data/OO_2D_randerasure/folder_3/'

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256,256])
Nepsilon = np.array([64,64])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
alpha = 0.1
beta = 1
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList = [0.2]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)

# %%
plots_coeffs(Nepsilon, NFine, alpha, beta, pList, "random_erasure")

# %%
NFine = np.array([256,256])
Nepsilon = np.array([64,64])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
alpha = 0.1
beta = 1
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList = [0.04, 0.06, 0.08, 0.1, 0.12]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)
root = 'All_Data/OO_2D_randerasure/folder_1/'

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]
