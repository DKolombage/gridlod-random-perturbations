# %%
import numpy as np
import scipy.io as sio
import time
from offline_online_alg import *
from convergence import *
from with_FEM_MassMatrix import *
from plots import *
from Experimental_Order_Cvg import *

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_2D_randcheck/folder_3/'

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([32, 32])
Nepsilon = np.array([32,32])
NCoarse = np.array([16,16])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 2
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.02,0.04,0.06,0.08,0.1, 0.15]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}

# %%
plot_offline_coeff(Nepsilon, NFine, NCoarse, k, alpha, beta, "checker_board")

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.02,0.04,0.06,0.08,0.1, 0.15]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_2D_randcheck/folder_6/'

# %%
plots_coeffs(Nepsilon, NFine, alpha, beta, pList, "rand_checkerboard")

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.04,0.06,0.08,0.1, 0.12]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_2D_randcheck/folder_7/'

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList =  [0.2]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}

# %%
plots_coeffs(Nepsilon, NFine, alpha, beta, pList, "rand_checkerboard")

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList =  [0.002,0.004,0.006,0.008,0.01]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_2D_randcheck/folder_4/'

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_2D_randcheck/folder_3/'

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_2D_randcheck/folder_3/'

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_2D_randcheck/folder_2/'

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
#convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "KOOLOD", reference_solver="FEM", save_files = True, plot=False, root=root)
