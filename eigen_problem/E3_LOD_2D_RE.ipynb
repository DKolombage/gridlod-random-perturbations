# %%
from with_FEM_MassMatrix import *
from convergence import *
from Reference_Solvers import *
from Experimental_Order_Cvg import *
from plots import *

# %%
alpha = 1
beta = 10
NSamples =200
pList = [0.05, 0.1, 0.15, 0.2]
NCoarse = np.array([4,4])
NFine = np.array([256, 256])   # Number of "fine-blocks" on τ_h mesh in each direction (1-D array: [x_h, y_h, z_h])
Nepsilon = np.array([128,128])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =3
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)
root = 'All_Data/LOD_2D_randerasure/folder_6/'

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
alpha = 1
beta = 10
NSamples =200
pList = [0.002,0.004,0.006,0.008,0.01]
NCoarse = np.array([4,4])
NFine = np.array([256, 256])   # Number of "fine-blocks" on τ_h mesh in each direction (1-D array: [x_h, y_h, z_h])
Nepsilon = np.array([128,128])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =3
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(1)
root = 'All_Data/LOD_2D_randerasure/folder_5_newbounds/'

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
alpha = 0.1
beta = 1.
NSamples =200
pList = [0.002,0.004,0.006,0.008,0.01]
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
NCoarse = np.array([4,4])
Nepsilon = np.array([128,128])
NFine = np.array([256,256])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =3
np.random.seed(1)
root = 'All_Data/LOD_2D_randerasure/folder_4/'
type = "random_erasure"

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
alpha = 0.1
beta = 1.
NSamples =200
pList = [0.02, 0.04, 0.06, 0.08, 0.1]
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
model = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
NCoarse = np.array([4,4])
Nepsilon = np.array([128,128])
NFine = np.array([256,256])    # Number of "epsilon-blocks" on τ_ε mesh in each direction (1-D array: [x_ε, y_ε, z_ε] if 3D etc.)     # Number of "coarse-blocks" on τ_H mesh in each direction (1-D array: [x_H, y_H, z_H]) # Number of layers in the patch 
Neigen = 3
k =3
np.random.seed(1)
root = 'All_Data/LOD_2D_randerasure/N200_Ppt02_pt1_5_K3/'
type = "random_erasure"

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]
