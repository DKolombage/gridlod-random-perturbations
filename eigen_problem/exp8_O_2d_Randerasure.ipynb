# %%
import numpy as np
import scipy.io as sio
import time
from offline_online_alg import *
from convergence import *
from with_FEM_MassMatrix import *
from plots import *
from Experimental_Order_Cvg import *

# %% [markdown]
# Experiment 1

# %%
NFine = np.array([256,256])
Nepsilon = np.array([128,128])
NCoarse = np.array([4,4])
k=1
NSamples = 2
dim = np.size(NFine)
Neigen = 3
alpha = 0.1
beta = 1
left = np.array([0.25, 0.25])
right = np.array([0.75, 0.75])
pList = [0.01, 0.05, 0.1, 0.15]
def_values = [alpha, 0.5, 5.]
modelincl = {'name': 'incl', 'bgval': alpha, 'inclval': beta, 'left': left, 'right': right}
np.random.seed(123)
root = 'Data/OO_2d_randerasure/N200_Ppt02_pt1_5_K1/'

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, modelincl, solver = "KOOLOD", reference_solver="FEM", save_files = True, plot=False, root=None)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# Root mean square absolute error of λ1:
#  [[0.60625806 0.22851747 0.29949624 0.92297538]
#  [0.61665433 0.23737163 0.29127755 0.90744229]
#  [0.60865603 0.21883012 0.30803876 0.91735044]
#  [0.73400476 0.32967318 0.21494775 0.84543189]]
# Root mean square absolute error of λ2:
#  [[0.92354993 0.48807298 0.06946941 0.66330003]
#  [0.85872025 0.42005859 0.1432838  0.72957886]
#  [0.751237   0.36320585 0.2001842  0.80588785]
#  [0.83906224 0.41818675 0.15248988 0.79093653]]
# (None, None)

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)

# %% [markdown]
# Before change

# %%
plots_coeffs(Nepsilon, NFine, alpha, beta, pList, type)

# %%
FEM_EigenSolver(Neigen, NSamples, pList,alpha,beta, NCoarse, NFine, Nepsilon, save_file=False)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# (array([[40.03380806, 40.06496504],
#         [43.28797693, 43.24629824],
#         [48.07778952, 47.41760329],
#         [53.33439055, 53.01756477]]),
#  array([[40.04655751, 40.08973766],
#         [43.41956016, 43.33422864],
#         [48.21710929, 47.81265101],
#         [53.45913968, 53.33803962]]))

# %%
KOOLOD_MFEM_EigenSolver(NCoarse, NFine, Nepsilon, k, alpha, beta, NSamples, pList, Neigen, modelincl, save_file=False)
# Out:
# (array([[48.33262867, 48.29066249],
#         [47.71157244, 47.70755345],
#         [46.90292294, 47.05363514],
#         [45.95829818, 46.18289364]]),
#  array([[53.07878417, 52.50911167],
#         [51.65659183, 51.66273324],
#         [51.21986776, 51.08055892],
#         [50.2639905 , 50.0568542 ]]))

# %%
KLOD_MFEM_EigenSolver(NCoarse, NFine, Nepsilon, k, alpha, beta, NSamples, pList, Neigen, modelincl,save_file=False)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 KLOD_MFEM_EigenSolver(NCoarse, NFine, Nepsilon, k, alpha, beta, NSamples, pList, Neigen, modelincl,save_file=False)
#
# File ~/Documents/gridlod-random-perturbations/eigen_problem/with_FEM_MassMatrix.py:70, in KLOD_MFEM_EigenSolver(NCoarse, NFine, Nepsilon, k, alpha, beta, NSamples, pList, Neigen, model, save_file)
#      67 IPatch = lambda: interp.L2ProjectionPatchMatrix(patchRef)
#      68 computeKmsijT = lambda TInd: computeKmsij(TInd, aPert, IPatch)
# ...

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model="modelincl", solver = "KOOLOD", reference_solver="FEM", save_files = True, plot=True, root=root)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model="modelincl", solver = "KOOLOD", reference_solver="FEM", save_files = True, plot=True, root=root)
#
# File ~/Documents/gridlod-random-perturbations/eigen_problem/convergence.py:24, in convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList, alpha, beta, model, solver, reference_solver, save_files, plot, root)
#      22 NCoarse *= 2
#      23 if reference_solver == "FEM" and solver == "KOOLOD":
# ---> 24     K_λ1, K_λ2 = KOOLOD_MFEM_EigenSolver(NCoarse, NFine, Nepsilon, k, alpha, beta, NSamples, pList, Neigen, model, save_file=False) #KLOD_MFEM_EigenSolver(NCoarse, NFine, Nepsilon, k, alpha, beta, NSamples, pList, Neigen, save_file=False)
# ...

# %%
plots_cvg(root=root, H_Convergence=True, p_Convergence=True)
