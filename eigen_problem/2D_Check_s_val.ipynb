# %%
from plots import *
import numpy as np

# %%
root1 = 'All_Data/OO_2D_randcheck/folder_sp/'
root2 ='All_Data/OO_2D_Rand_sval/folder_sp/'

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
plot_OLO_p(root1, root2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# abs

# %%
plot_OLO_p(root1, root2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[0.24088489 0.30227003 0.2902276  0.27700292 0.26564885]]

# %% [markdown]
# relative

# %%
plot_OLO_p(root1, root2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[0.24088489 0.30227003 0.2902276  0.27700292 0.26564885]]

# %%
root1 = 'All_Data/OO_2D_randcheck/folder_sp/'
root2 ='All_Data/OO_2D_Rand_sval/folder_sp/'

# %% [markdown]
# Relative

# %%
plot_OLO_p(root1, root2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[0.24088489 0.30227003 0.2902276  0.27700292 0.26564885]]

# %% [markdown]
# absolute

# %%
plot_OLO_p(root1, root2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[0.24088489 0.30227003 0.2902276  0.27700292 0.26564885]]

# %%
plot_p_vs_s(root2, xlabel="$p-$values", ylabel="$s-$values", title=None)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
root1 = 'All_Data/OO_2D_randcheck/folder_7/'
root2 ='All_Data/OO_2D_Rand_sval/folder_1/'

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128, 128])
NCoarse = np.array([4, 4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.002,0.004,0.006,0.008, 0.01]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_2D_Rand_sval/folder_2/'

# %%
plots_cvg(root, H_Convergence=False, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256, 256])
Nepsilon = np.array([128, 128])
NCoarse = np.array([4, 4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.04,0.06,0.08,0.1, 0.12]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}

# %%
root1 ='All_Data/OO_2D_Rand_sval/folder_1/'

# %%
plots_cvg(root1, H_Convergence=False, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
plot_p_vs_s(root1)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
