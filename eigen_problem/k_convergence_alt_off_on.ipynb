# %%
from k_convergence_alt_off_on import *

# %%
root='All_Data/k_cvg_alternate/'

# %%
k_convergence(1, 3, root)
# Out:
# one dimensional with $nk=3$ and $nH=8$, $n\epsilon = 128$, $nh=256$
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# [[ 0.56972148  1.38515803]
#  [ 1.37542932  0.57554867]
#  [ 1.37542932 -0.57554867]
#  [ 0.56972148 -1.38515803]
#  [-0.56972148 -1.37291712]
#  [-1.37542932 -0.54608879]
#  [-1.37542932  0.54608879]
#  [-0.56972148  1.37291712]]
# [[-0.2794677   1.41268572]
#  [-0.79585666  1.20084971]
#  [-1.19108367  0.80365714]
#  [-1.40497898  0.28241646]
#  [-1.40497898 -0.28241646]
#  [-1.19108367 -0.80365714]
#  [-0.79585666 -1.20084971]
#  [-0.2794677  -1.41268572]
#  [ 0.2794677  -1.40646732]
#  [ 0.79585666 -1.18315436]
#  [ 1.19108367 -0.77721618]
#  [ 1.40497898 -0.25131119]
#  [ 1.40497898  0.25131119]
#  [ 1.19108367  0.77721618]
# ...

# %%
k_convergence_plots(1, 3, root=root) #p=0.05

# %%
root='All_Data/k_cvg_alternate/'

# %%
k_convergence(1, 3, root) #p=0.01
# Out:
# one dimensional with $nk=3$ and $nH=8$, $n\epsilon = 128$, $nh=256$
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# [[ 0.56972148  1.38515803]
#  [ 1.37542932  0.57554867]
#  [ 1.37542932 -0.57554867]
#  [ 0.56972148 -1.38515803]
#  [-0.56972148 -1.37291712]
#  [-1.37542932 -0.54608879]
#  [-1.37542932  0.54608879]
#  [-0.56972148  1.37291712]]
# [[-0.2794677   1.41268572]
#  [-0.79585666  1.20084971]
#  [-1.19108367  0.80365714]
#  [-1.40497898  0.28241646]
#  [-1.40497898 -0.28241646]
#  [-1.19108367 -0.80365714]
#  [-0.79585666 -1.20084971]
#  [-0.2794677  -1.41268572]
#  [ 0.2794677  -1.40646732]
#  [ 0.79585666 -1.18315436]
#  [ 1.19108367 -0.77721618]
#  [ 1.40497898 -0.25131119]
#  [ 1.40497898  0.25131119]
#  [ 1.19108367  0.77721618]
# ...

# %%
k_convergence_plots(1, 3, root=root) #p=0.01

# %%
k_convergence_plots(1, 3, root=root)

# %%
root = 'All_Data/k_convergency/1D_k4'
alpha = 0.1
beta = 1.
NSamples =1
pList = [0.01]
model ={'name': 'check', 'alpha': alpha, 'beta': beta}

# %%
k_convergence(1, 4,root)
# Out:
# one dimensional with $nk=4$ and $nH=16$, $n\epsilon = 256$, $nh=512$

# %%
k_convergence_plots(1, 4, root=root)

# %%
k_convergence_plots(1, 4, root=root)

# %%
root =  'All_Data/k_convergency/2D'

# %%
k_convergence(2, 3, root)
# Out:
# Two dimensional with $nk=3$ and $nH=8$, $n\epsilon = 128$, $nh=256$
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %%
k_convergence_plots(2, 3, root=root)

# %%
k_convergence(2, 3, root)
# Out:
# Two dimensional with nk=3 and nH=8, n\epsilon = 128, nh=256
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %%
k_convergence_plots(2, 3, root=root)
