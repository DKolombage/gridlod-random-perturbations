# %%
import numpy as np
import scipy.io as sio
import time
from offline_online_alg import *
from convergence import *
from with_FEM_MassMatrix import *
from Experimental_Order_Cvg import *
from plots import *

# %%
NFine = np.array([256])
Nepsilon = np.array([128])
NCoarse = np.array([16])
k=1
NSamples = 2
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.01, 0.02, 0.03]
np.random.seed(123)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = None

# %%
FEM_EigenSolver(Neigen, NSamples, pList,alpha,beta, NCoarse, NFine, Nepsilon, save_file=False)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# (array([[3.94831647, 3.94834043],
#         [3.94850849, 3.97849711],
#         [4.0317518 , 4.04362965]]),
#  array([[4.0042175 , 4.00406298],
#         [4.00473018, 4.14833786],
#         [4.09480755, 4.13993247]]))

# %%
KOOLOD_MFEM_EigenSolver(NCoarse, NFine, Nepsilon, k, alpha, beta, NSamples, pList, Neigen, model, save_file=False)
# Out:
# (array([[3.99883226, 3.99883226],
#         [3.99883226, 4.02206187],
#         [4.09105201, 4.07032798]]),
#  array([[4.05581423, 4.05581423],
#         [4.05581423, 4.19855582],
#         [4.14025621, 4.22068931]]))

# %%
KLOD_MFEM_EigenSolver(NCoarse, NFine, Nepsilon, k, alpha, beta, NSamples, pList, Neigen, save_file=False)
# Out:
# (array([[3.97003608, 3.97009318],
#         [3.97009551, 3.99840491],
#         [4.0530094 , 4.06303607]]),
#  array([[4.02483752, 4.02455695],
#         [4.02684958, 4.18023973],
#         [4.11360572, 4.18215287]]))

# %%
convergence(Neigen, NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, model, solver = "LOD", reference_solver="FEM", save_files = True, plot=True, root=None)
# Out:
# /home/kolombag/Documents/gridlod-random-perturbations/venv3/lib/python3.9/site-packages/scipy/sparse/_index.py:137: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)
# Hplot [array(32), array(64), array(128), array(256)]
# Root mean square absolute error of λ1:
#  [[0.00610068 0.00383815 0.01822646]
#  [0.00161303 0.00258153 0.01026892]
#  [0.00060526 0.00108745 0.00193747]
#  [0.00021836 0.00066379 0.00024426]]
# Root mean square absolute error of λ2:
#  [[0.01790608 0.0281647  0.03345912]
#  [0.00709679 0.01859463 0.02012985]
#  [0.00050903 0.00066352 0.00160077]
#  [0.00012859 0.00038776 0.00019757]]
# (None, None)

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)

# %%
EOC(NCoarse, NFine, Nepsilon, k, NSamples, pList,alpha,beta, Neigen, root = None, use_stored_data=True)
# Out:
# Experimental Order of Convergence for λ1:
#  [array([-2.38389665, -1.28061269, -0.70262307]), array([-1.55817887, -1.29157395, -4.85729353]), array([-2.31973236, -0.93222908, -2.87818626])]
# Experimental Order of Convergence for λ2:
#  [array([-1.30403311, -0.55599276, -0.6286018 ]), array([-3.68372349, -4.37156262, -6.66899372]), array([ 0.06181475, -0.24729677,  0.30218234])]
# Set of Coarse elements:
#  [ 32  64 128 256]
# (None, None, None)
