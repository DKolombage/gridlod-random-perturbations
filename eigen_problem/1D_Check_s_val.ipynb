# %%
from plots import *
import numpy as np

# %%
root1 ='All_Data/OO_1D_Rand_sval/folder_3/'
root2='All_Data/OO_1D_randcheck/folder_1/'

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
plot_s_vs_unity_errors(root1, root2)

# %%
plots_cvg(root1, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256])
Nepsilon = np.array([128])
NCoarse = np.array([4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.04,0.06,0.08,0.1, 0.12]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root2 = 'All_Data/OO_1D_Rand_sval/folder_3/'

# %%
plots_cvg(root2, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
plot_p_vs_s(root2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256])
Nepsilon = np.array([128])
NCoarse = np.array([4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.002,0.004,0.006,0.008,0.01]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_1D_Rand_sval/folder_2/'

# %%
plot_p_vs_s(root)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]

# %%
NFine = np.array([256])
Nepsilon = np.array([128])
NCoarse = np.array([4])
k=3
NSamples = 200
dim = np.size(NFine)
Neigen = 3
boundaryConditions = None
alpha = 0.1
beta = 1.
pList = [0.02,0.04,0.06,0.08,0.1]
np.random.seed(1)
model ={'name': 'check', 'alpha': alpha, 'beta': beta}
root = 'All_Data/OO_1D_Rand_sval/folder_1/'

# %%
plot_p_vs_s(root)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plots_cvg(root, H_Convergence=True, p_Convergence=True)
# Out:
# hplot [ 8 16 32 64]
